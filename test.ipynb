# %% [markdown]
# ### Load SQL

# %%
# %load_ext sql

# %% [markdown]
# ### Make Connections to DB

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %% [markdown]
# ### songs Table QA

# %%
# %sql SELECT * FROM songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, Decimal('218.93179'))]

# %% [markdown]
# ### artists Table QA

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN'))]

# %% [markdown]
# ### time Table QA

# %%
# %sql SELECT COUNT(*) FROM time;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(330,)]

# %%
# %sql SELECT * FROM time LIMIT 3
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 3 rows affected.
# [(datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 0, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 1, 30, 48, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 1, 30, 48, 11, 2018, 4)]

# %% [markdown]
# ### users Table QA

# %%
# %sql SELECT * FROM users ORDER BY 1 ASC;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 22 rows affected.
# [(5, 'Elijah', 'Davis', 'M', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (16, 'Rylan', 'George', 'M', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (30, 'Avery', 'Watkins', 'F', 'paid'),
#  (33, 'Bronson', 'Harris', 'M', 'free'),
#  (36, 'Matthew', 'Jones', 'M', 'paid'),
#  (43, 'Jahiem', 'Miles', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'paid'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (57, 'Katherine', 'Gay', 'F', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (73, 'Jacob', 'Klein', 'M', 'paid'),
#  (74, 'Braden', 'Parker', 'M', 'free'),
#  (78, 'Chloe', 'Roth', 'F', 'free'),
#  (85, 'Kinsley', 'Young', 'F', 'paid'),
#  (86, 'Aiden', 'Hess', 'M', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'paid'),
#  (91, 'Jayden', 'Bell', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (101, 'Jayden', 'Fox', 'M', 'free')]

# %%
# %sql SELECT s.song_id, s.artist_id FROM songs s JOIN artists a ON s.artist_id = a.artist_id;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1')]

# %% [markdown]
# ### songplays Table QA

# %%
# %sql SELECT * FROM songplays order by 1 asc;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1320 rows affected.
# [(1, datetime.datetime(2018, 11, 30, 12, 22, 7), 91, 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  (2, datetime.datetime(2018, 11, 30, 12, 22, 7), 91, 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  (3, datetime.datetime(2018, 11, 30, 1, 8, 41), 73, 'paid', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %%
# %sql describe time;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# (psycopg2.ProgrammingError) syntax error at or near "describe"
# LINE 1: describe time;
#         ^
#  [SQL: 'describe time;']

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
